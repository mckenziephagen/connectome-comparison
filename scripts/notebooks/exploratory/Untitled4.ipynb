# %%
import pickle
import os.path as op
from glob import glob

# %%
results_path = '/global/homes/m/mphagen/functional-connectivity/connectome-comparison/results'

# %%
def get_files(derivatives, proc_type, model_id): 
    conn_path = op.join(derivatives, 'connectivity-matrices', proc_type, model_id) 
    result_files = glob(op.join(conn_path, 'sub-*', '*.pkl'))
    return result_files

# %%
file = '/pscratch/sd/m/mphagen/human-connectome-project-openaccess/HCP1200/derivatives/connectivity-matrices/MSMAll_FIX/correlation_ses/sub-174841/sub-174841_task-rest_ses-full_fsLR_seg-4S156Parcels_den-91k_model-correlation_cv-ses_results.pkl'

# %%
old_fix = '/global/homes/m/mphagen/functional-connectivity/connectome-comparison/results/MSMAll/2025-12-10_task-rest_space-fsLR_seg-4S156Parcels_den-91k_model-correlation_ses_stat-median_relmat.pkl'

# %%
new_fix = '/global/homes/m/mphagen/functional-connectivity/connectome-comparison/results/MSMAll_FIX/2026-05-22_task-rest_space-fsLR_seg-4S156Parcels_den-91k_model-correlation_ses_relmat.pkl'

# %%
with open(new_fix, 'rb') as f: 
    new_fix_dict = pickle.load(f)

# %%
with open(old_fix, 'rb') as f: 
    old_fix_dict = pickle.load(f)

# %%
new_fix_dict.keys()
# Out:
# dict_keys(['sub-793465', 'sub-174841', 'sub-979984', 'sub-826454', 'sub-788674', 'sub-204521', 'sub-947668', 'sub-134425', 'sub-102109', 'sub-231928', 'sub-673455', 'sub-887373', 'sub-153126', 'sub-899885', 'sub-176239', 'sub-134728', 'sub-579665', 'sub-406836', 'sub-156031', 'sub-159441', 'sub-531536', 'sub-704238', 'sub-202113', 'sub-162935', 'sub-882161', 'sub-552241', 'sub-770352', 'sub-180533', 'sub-169949', 'sub-117930', 'sub-130114', 'sub-111413', 'sub-590047', 'sub-118932', 'sub-100307', 'sub-102008', 'sub-937160', 'sub-300719', 'sub-176744', 'sub-130013', 'sub-341834', 'sub-342129', 'sub-105014', 'sub-159138', 'sub-837560', 'sub-130316', 'sub-597869', 'sub-930449', 'sub-559053', 'sub-103010', 'sub-136732', 'sub-742549', 'sub-100408', 'sub-878877', 'sub-208630', 'sub-959574', 'sub-107018', 'sub-871762', 'sub-118225', 'sub-333330', 'sub-130417', 'sub-353740', 'sub-160729', 'sub-175237', 'sub-141422', 'sub-368753', 'sub-149236', 'sub-635245', 'sub-107321', 'sub-680250', 'sub-90
# ...

# %%
sum(new_fix_dict['sub-793465']['ses-1'] != old_fix_dict['sub-793465']['ses-1'])
# Out:
# array([99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99,
#        99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99,
#        99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99,
#        99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99,
#        99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99,
#        99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99])
