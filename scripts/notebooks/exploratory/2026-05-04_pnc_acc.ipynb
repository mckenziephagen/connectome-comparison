# %%
import pandas as pd
import seaborn as sns 

from scipy import stats

# %%
pnc_df = pd.read_csv('/global/homes/m/mphagen/functional-connectivity/connectome-comparison/scripts/notebooks/02-Analysis/results/2026_05_02_PNC_acc.csv', 
                           index_col=['fold', 'node'])

# %%
np.mean(pnc_df.loc['fold_0'], axis=1)
# Out:
# node
# node_0    -0.497780
# node_1     0.072151
# node_2     0.146215
# node_3    -0.229500
# node_4    -0.047855
#              ...
# node_95    0.408493
# node_96    0.403461
# node_97    0.323350
# node_98    0.383928
# node_99    0.580729
# Length: 100, dtype: float64

# %%
np.mean(pnc_df.loc['fold_1'], axis=1)
# Out:
# node
# node_0    -0.123467
# node_1     0.381283
# node_2     0.173510
# node_3     0.100954
# node_4     0.219529
#              ...
# node_95    0.622884
# node_96    0.584549
# node_97    0.484881
# node_98    0.438367
# node_99    0.643783
# Length: 100, dtype: float64

# %%
np.mean(pnc_df.loc['fold_0'], axis=0)
# Out:
# sub-4164375240    0.414619
# sub-3289273628   -0.048188
# sub-429608771     0.280284
# sub-2906198493    0.002538
# sub-2925300630    0.127024
#                     ...
# sub-4063155703    0.513796
# sub-4174857942   -0.144375
# sub-1177503761    0.041626
# sub-1017092387    0.259370
# sub-3095311898    0.220939
# Length: 693, dtype: float64

# %%
np.mean(pnc_df.loc['fold_1'], axis=0)
# Out:
# sub-4164375240    0.578841
# sub-3289273628    0.311473
# sub-429608771     0.434313
# sub-2906198493    0.329792
# sub-2925300630    0.431528
#                     ...
# sub-4063155703    0.442167
# sub-4174857942    0.207969
# sub-1177503761    0.352952
# sub-1017092387    0.477637
# sub-3095311898    0.459953
# Length: 693, dtype: float64

# %%
sns.heatmap(pnc_df.loc['fold_0'] - pnc_df.loc['fold_1'], vmin=-10)
# Out:
# <Axes: ylabel='node'>

# %%
sns.heatmap(pnc_df.loc['fold_1'])
# Out:
# <Axes: ylabel='node'>

# %%
data=np.abs(stats.zscore(r2_df.loc['fold_0']))

# %%
sns.heatmap(abs(stats.zscore(pnc_df.loc['fold_0'])))
# Out:
# <Axes: >

# %%
sns.heatmap(abs(stats.zscore(pnc_df.loc['fold_1'])))
# Out:
# <Axes: >

# %%
plt.hist(np.array(pnc_df.loc['fold_0']).ravel()) 
plt.semilogy()
# Out:
# []

# %%
plt.hist(np.array(pnc_df.loc['fold_1']).ravel()) 
plt.semilogy()
# Out:
# []
