# %%
#look at autocorrelation function for problematic nodes
#look at very high performing nodes

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
r2_df = pd.read_csv('2025-10-24_r2.csv').set_index(["fold", "node"])

# %%
r2_df.mean(axis=1)['fold_0']
# Out:
# node
# node_0     0.346020
# node_1     0.662845
# node_2     0.691736
# node_3     0.540583
# node_4     0.641973
#              ...
# node_95    0.646880
# node_96    0.781176
# node_97    0.741139
# node_98    0.575377
# node_99    0.770867
# Length: 100, dtype: float64

# %%
r2_df.mean(axis=1)['fold_0']

# %%
plt.hist(r2_df.mean(axis=0))
# Out:
# (array([ 1.,  1.,  2., 14., 11., 13., 25., 13., 17.,  3.]),
#  array([0.50926339, 0.53258464, 0.55590589, 0.57922714, 0.60254839,
#         0.62586964, 0.64919088, 0.67251213, 0.69583338, 0.71915463,
#         0.74247588]),
#  <BarContainer object of 10 artists>)

# %%
r2_df.loc['fold_0'].mean(axis=1).sort_values().to_csv('node_r2.csv')

# %%
r2_df.loc['fold_0'].mean(axis=1).sort_values()
# Out:
# node
# node_30   -0.502863
# node_41    0.012629
# node_78    0.195973
# node_50    0.216096
# node_79    0.231507
#              ...
# node_89    0.828334
# node_81    0.843364
# node_40    0.846526
# node_56    0.855639
# node_7     0.871666
# Length: 100, dtype: float64

# %%
r2_df.loc['fold_1'].mean(axis=1).sort_values()
# Out:
# node
# node_30   -0.494136
# node_41    0.024535
# node_79    0.246217
# node_78    0.259447
# node_50    0.309287
#              ...
# node_69    0.842687
# node_40    0.845701
# node_81    0.845821
# node_56    0.864488
# node_7     0.869644
# Length: 100, dtype: float64

# %%
r2_df.loc['fold_2'].mean(axis=1).sort_values()
# Out:
# node
# node_30    0.175745
# node_78    0.253191
# node_31    0.350047
# node_50    0.367902
# node_0     0.418231
#              ...
# node_45    0.856792
# node_81    0.863606
# node_56    0.872196
# node_40    0.885208
# node_7     0.893123
# Length: 100, dtype: float64

# %%
r2_df.loc['fold_3'].mean(axis=1).sort_values()
# Out:
# node
# node_78   -0.455842
# node_93    0.029230
# node_31    0.155346
# node_30    0.182012
# node_0     0.320119
#              ...
# node_81    0.845296
# node_69    0.848384
# node_56    0.854757
# node_40    0.872600
# node_7     0.884867
# Length: 100, dtype: float64

# %%
r2_df.loc['fold_4'].mean(axis=1).sort_values()
# Out:
# node
# node_78   -0.518169
# node_93   -0.004991
# node_31    0.146744
# node_30    0.225202
# node_0     0.309099
#              ...
# node_99    0.849573
# node_56    0.850444
# node_45    0.855222
# node_7     0.876907
# node_40    0.877541
# Length: 100, dtype: float64
