# %%
from glob import glob
import os.path as op
from numpy.linalg import norm
import pickle

# %%
xcpd_pkl = '/global/homes/m/mphagen/functional-connectivity/connectome-comparison/results/xcpd/2025-10-01_task-rest_space-fsLR_seg-4S156Parcels_den-91k_model-lassoBIC_stat-median_relmat.pkl'

# %%
msmall_pkl = '/global/homes/m/mphagen/functional-connectivity/connectome-comparison/results/MSMAll/2025-09-26_task-rest_space-fsLR_seg-4S156Parcels_den-91k_model-lassoBIC_stat-median_relmat.pkl'

# %%
with open(xcpd_pkl, 'rb') as l:
        xcpd_dict = pickle.load(l)

# %%
with open(msmall_pkl, 'rb') as l:
        msmall_dict = pickle.load(l)

# %%
for sub in xcpd_dict.keys(): 
    for ses in xcpd_dict[sub].keys(): 
        print(norm(xcpd_dict[sub][ses], 'fro'))
# Out:
# 15.312680441206618
# 14.92577627705402
# 15.507620427456752
# 15.470698973946009
# 15.193546554132817
# 15.28217932712932
# 15.201250819281801
# 14.994231176542275
# 15.26014335304461
# 16.189191093303688
# 15.55671679355832
# 15.37883022869286
# 15.051904153632805
# 15.643810916309343
# 15.468688758054423
# 15.082347179316999
# 15.11391108161763
# 15.566309412805639
# 16.270306482506044
# 16.214005383965205
# 15.189991207783141
# 15.323756921909592
# 15.224873045620278
# 14.728053009805862
# 14.946230833550297
# 14.930516097411113
# 15.239775867261208
# 15.480080274811266
# 15.491560577904757
# 15.244091110505881
# 15.743284209008046
# 15.248085688631852
# 15.491436245325406
# 15.518769078120611
# 15.345349697701797
# 15.188688435214251
# 14.391178681699415
# 14.340928587581216
# 14.494040571127421
# 14.537796752339004
# 14.984928491793813
# 15.15247728258868
# 14.886964825483204
# 14.95638061313735
# 15.111857580499947
# 14.61411828219452
# 15.311739650006418
# 15.094202763807385
# ...
