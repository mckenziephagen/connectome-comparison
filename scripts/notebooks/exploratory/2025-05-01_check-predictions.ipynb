# %%
import pickle

# %%
path = '/global/homes/m/mphagen/functional-connectivity/connectome-comparison/scripts/processing/notebook_results/sub-102311_task-rest_ses-full_fsLR_seg-4S156Parcels_den-91k_model-lassoBIC_cv-ses_results.pkl'

# %%
with open(path, 'rb') as f: 
    res_dict = pickle.load(f)
# Out:
# /global/homes/m/mphagen/miniconda3/envs/pyuoi/lib/python3.13/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator LassoLarsIC from version 1.7.1 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
res_dict.keys()
# Out:
# dict_keys(['full_fc_matrix', 'fold_0', 'fold_1'])

# %%
res_dict['fold_0']
# Out:
# {'node_0': {'train_r2': 0.4552783966064453,
#   'test_r2': 0.5700670480728149,
#   'model': LassoLarsIC(criterion='bic', max_iter=1000)},
#  'node_1': {'train_r2': 0.8369654417037964,
#   'test_r2': 0.8727596998214722,
#   'model': LassoLarsIC(criterion='bic', max_iter=1000)},
#  'node_2': {'train_r2': 0.7717121243476868,
#   'test_r2': 0.824309229850769,
#   'model': LassoLarsIC(criterion='bic', max_iter=1000)},
#  'node_3': {'train_r2': 0.8161625266075134,
#   'test_r2': 0.8636301755905151,
#   'model': LassoLarsIC(criterion='bic', max_iter=1000)},
#  'node_4': {'train_r2': 0.8820227980613708,
#   'test_r2': 0.8670015335083008,
#   'model': LassoLarsIC(criterion='bic', max_iter=1000)},
#  'node_5': {'train_r2': 0.8456083536148071,
#   'test_r2': 0.8694623708724976,
#   'model': LassoLarsIC(criterion='bic', max_iter=1000)},
#  'node_6': {'train_r2': 0.8475101590156555,
#   'test_r2': 0.845917284488678,
#   'model': LassoLarsIC(criterion='bic', max_iter=1000)},
# ...

# %%
for ii in range(1,10): 
    print(res_dict['fold_0'][f'node_{ii}']['model'].criterion_)
# Out:
# [15096.71191406  9960.90627089  8969.30765897  7154.29693767
#   5891.49568903  5648.27695993  5139.12219566  3918.7564939
#   3501.40421987  3278.59857669  3277.26681048  3204.39427277
#   3046.7021341   3032.77049348  2904.98340499  2859.08742979
#   2854.92582959  2857.30622157  2844.71835184  2846.19615593
#   2838.29432136  2815.71914694  2807.25603306  2791.42988208
#   2796.88913148  2800.04808792  2778.31153655  2784.93582502
#   2787.63164669  2774.85798594  2773.87753808  2777.32873085
#   2776.12635916  2763.64442557  2762.47840994  2749.15592107
#   2756.76824665  2760.80659762  2762.81687241  2762.49780151
#   2770.14333021  2762.87917006  2756.82887709  2746.56131985
#   2750.47222942  2751.42366632  2751.21885323  2754.34387412
#   2752.60952001  2753.12858387  2750.54095828  2753.50435808
#   2759.20555085  2757.21582564  2759.67336607  2763.50248852
#   2768.02252894  2774.7344639   2782.02550041  2788.83753302
# ...
