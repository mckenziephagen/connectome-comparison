# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
msmall_lasso_icc = pd.read_csv('../02-Analysis/results/lasso_msmall_lme_icc.csv', header=None, skiprows=1)

# %%
np.nanmean(msmall_lasso_icc)
# Out:
# np.float64(0.18198985191955283)

# %%
sns.boxplot(msmall_lasso_icc.dropna(axis=1).T)
# Out:
# <Axes: >
