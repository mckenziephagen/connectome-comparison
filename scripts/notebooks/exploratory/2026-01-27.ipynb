# %%
import nibabel as nb

# %%
pconn_file = '/pscratch/sd/m/mphagen/sub-1616242378_ses-PNC1_task-rest_acq-singleband_space-fsLR_seg-4S156Parcels_den-91k_stat-pearsoncorrelation_boldmap.pconn.nii'

# %%
pconn = nb.load(pconn_file) 
conn_mat = pconn.get_fdata()

# %%
conn_mat
# Out:
# memmap([[ 1.        ,  0.36396676,  0.53158289, ...,  0.0460595 ,
#           0.05473896, -0.05559928],
#         [ 0.36396676,  1.        ,  0.64755863, ..., -0.51393116,
#          -0.1602843 , -0.31735545],
#         [ 0.53158289,  0.64755863,  1.        , ..., -0.14911255,
#           0.21468762, -0.13525939],
#         ...,
#         [ 0.0460595 , -0.51393116, -0.14911255, ...,  1.        ,
#           0.7050792 ,  0.1029086 ],
#         [ 0.05473896, -0.1602843 ,  0.21468762, ...,  0.7050792 ,
#           1.        , -0.07498969],
#         [-0.05559928, -0.31735545, -0.13525939, ...,  0.1029086 ,
#          -0.07498969,  1.        ]], shape=(156, 156))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(conn_mat[:100, :100])

# %%
plt.imshow(conn_mat)
