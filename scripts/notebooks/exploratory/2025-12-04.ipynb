# %%
from _functions import extract_r2
from functools import reduce
from operator import getitem
import numpy as np

# %%
import pickle

# %%
ses_results = '/global/homes/m/mphagen/functional-connectivity/connectome-comparison/scripts/processing/notebook_results/sub-100206_task-rest_ses-1_fsLR_seg-4S156Parcels_den-91k_model-lassoBIC_results.pkl'
block_results = '/global/homes/m/mphagen/functional-connectivity/connectome-comparison/scripts/processing/notebook_results/sub-100206_task-rest_ses-both_fsLR_seg-4S156Parcels_den-91k_model-lassoBIC_cv-blocks_results.pkl'
run_results = '/global/homes/m/mphagen/functional-connectivity/connectome-comparison/scripts/processing/notebook_results/sub-100206_task-rest_ses-both_fsLR_seg-4S156Parcels_den-91k_model-lassoBIC_cv-run_results.pkl'

# %%
with open(ses_results, 'rb') as f:
    ses_res = pickle.load(f)

# %%
with open(run_results, 'rb') as f:
    run_res = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 with open(run_results, 'rb') as f:
#       2     run_res = pickle.load(f)
#
# File ~/miniconda3/envs/fc_py311/lib/python3.13/site-packages/IPython/core/interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     319 if file in {0, 1, 2}:
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
fold_1 = []
for jj in range(0,100): 
    fold_1.append(reduce(getitem, (f'fold_1', f'node_{jj}', 'test_r2'), block_res) )

# %%
fold_0 = []
for jj in range(0,100): 
    fold_0.append(reduce(getitem, (f'fold_0', f'node_{jj}', 'test_r2'), block_res) )
