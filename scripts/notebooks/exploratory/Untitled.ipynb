# %%
import pickle

# %%
pkl_file = '/global/homes/m/mphagen/functional-connectivity/connectome-comparison/scripts/processing/notebook_results/sub-200513_task-rest_ses-1_fsLR_seg-4S156Parcels_den-91k_model-lassoBIC_results.pkl'

# %%
with open(pkl_file, 'rb') as f:
    results = pickle.load(f)

# %%
results.keys()
# Out:
# dict_keys(['fold_0', 'fold_1', 'fold_2', 'fold_3', 'fold_4'])

# %%
results['fold_0']['node_2']['model'].get_params()
# Out:
# {'alpha': np.float32(0.0008331952),
#  'copy_X': True,
#  'eps': np.float64(2.220446049250313e-16),
#  'fit_intercept': True,
#  'fit_path': True,
#  'jitter': None,
#  'max_iter': 500,
#  'positive': False,
#  'precompute': 'auto',
#  'random_state': None,
#  'verbose': False}

# %%
?
